# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
mypath = '/content/gdrive/My Drive/Drive Tugas Akhir/Dataset/Drishti-GS1_files/Drishti-GS1_files/Training/Images/'

file_name = []
full_path = []
for path, subdirs, files in os.walk(mypath):
    for name in files:
        full_path.append(os.path.join(path, name))      
        file_name.append(name)
    break

# %%
import pandas as pd
# memasukan variabel yang sudah dikumpulkan pada looping di atas menjadi sebuah dataframe agar rapih
df = pd.DataFrame({"path":full_path,'file_name':file_name})
df.head()
# Out:
#                                                 path          file_name
# 0  /content/gdrive/My Drive/Drive Tugas Akhir/Dat...  drishtiGS_002.png
# 1  /content/gdrive/My Drive/Drive Tugas Akhir/Dat...  drishtiGS_004.png
# 2  /content/gdrive/My Drive/Drive Tugas Akhir/Dat...  drishtiGS_008.png
# 3  /content/gdrive/My Drive/Drive Tugas Akhir/Dat...  drishtiGS_010.png
# 4  /content/gdrive/My Drive/Drive Tugas Akhir/Dat...  drishtiGS_012.png

# %% [markdown]
# Manually select OD centroid

# %%
def click_event(event, x, y, flags, params):
  if event == cv2.EVENT_LBUTTONDOWN: 
  
        # displaying the coordinates 
        # on the Shell 
        print(x, ' ', y)

# %%
import cv2
from google.colab.patches import cv2_imshow

#for i in range(len(df["path"])):
src = cv2.imread(df["path"][1], 1)
img = src[:,:,1] # green channel
# Out:
# <PIL.Image.Image image mode=L size=2049x1762 at 0x7F9E52AB74A8>
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-76-90e0f988ab0b> in <module>()
#       7
#       8 cv2_imshow(img)
# ----> 9 cv2.setMouseCallback('image', click_event)
#      10 cv2.waitKey(0)
#      11 cv2.destroyAllWindows()
#
# error: OpenCV(4.1.2) /io/opencv/modules/highgui/src/window_QT.cpp:714: error: (-27:Null pointer) NULL window handler in function 'cvSetMouseCallback'
